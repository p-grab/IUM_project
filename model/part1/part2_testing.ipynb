# %%
import pandas as pd
import numpy as np

model_baseline = pd.read_csv("artifacts/ab_test/model_baseline.csv")
model_advanced = pd.read_csv("artifacts/ab_test/model_advanced2.csv")
print("Baseline model shape:", model_baseline.shape)
print("Advanced model shape:", model_advanced.shape)
print("\nBaseline columns:", model_baseline.columns.tolist())
print("Advanced columns:", model_advanced.columns.tolist())
print("\nBaseline sample:")
print(model_baseline.head())
print("\nAdvanced sample:")
print(model_advanced.head())
# Out:
# Baseline model shape: (2150670, 8)
# Advanced model shape: (4116325, 8)
#
# Baseline columns: ['listing_id', 'aspect', 'date', 'negative', 'neutral', 'positive', 'score', 'total_mentions']
# Advanced columns: ['listing_id', 'aspect', 'date', 'negative', 'neutral', 'positive', 'score', 'total_mentions']
#
# Baseline sample:
#    listing_id              aspect        date  negative  neutral  positive  \
# 0        2737         cleanliness  2015-01-04       0.0      0.0       1.0
# 1        2737         cleanliness  2015-04-22       0.0      0.0       1.0
# 2        2737   host_and_property  2015-04-22       0.0      0.0       1.0
# 3        2737  host_communication  2015-01-04       0.0      0.0       2.0
# 4        2737         walkability  2014-12-26       0.0      0.0       1.0
#
#    score  total_mentions
# 0    1.0             1.0
# 1    1.0             1.0
# 2    1.0             1.0
# 3    2.0             2.0
# 4    1.0             1.0
#
# Advanced sample:
#    listing_id                 aspect        date  negative  neutral  positive  \
# 0        2737    apartment_amenities  2015-04-22       0.0      0.0       1.0
# 1        2737      apartment_quality  2014-12-26       0.0      0.0       1.0
# 2        2737      apartment_quality  2015-04-22       0.0      0.0       1.0
# 3        2737  host_arrival_services  2015-01-04       0.0      0.0       2.0
# 4        2737  host_arrival_services  2015-04-12       0.0      0.0       2.0
#
#    score  total_mentions
# 0    1.0             1.0
# 1    1.0             1.0
# 2    1.0             1.0
# 3    2.0             2.0
# 4    2.0             2.0

# %%
baseline_sentences = pd.read_csv("artifacts/BASE_sentences_for_aspects_eng_WITH_ASPECTS.csv")
advanced_sentences = pd.read_csv("artifacts/sentences_with_sentiment_all_top10_all_final_WITH_ASPECTS2.csv")
print("Baseline sentences shape:", baseline_sentences.shape)
print("Advanced sentences shape:", advanced_sentences.shape)
print("Baseline columns:", baseline_sentences.columns.tolist())
print("Advanced columns:", advanced_sentences.columns.tolist())
# Out:
# Baseline sentences shape: (4177443, 6)
# Advanced sentences shape: (5262669, 7)
# Baseline columns: ['listing_id', 'sentence', 'date', 'cluster', 'aspect', 'sentiment']
# Advanced columns: ['listing_id', 'sentence', 'date', 'cluster_kmeans', 'cluster_merged', 'sentiment', 'aspect']

# %%
np.random.seed(42)

baseline_valid = baseline_sentences[baseline_sentences['aspect'].notna()].copy()
baseline_sample_100 = baseline_valid.sample(n=100, random_state=123)
advanced_sample_100 = advanced_sentences.sample(n=100, random_state=456)

print("BASELINE MODEL - 100 Random Sentences")
for idx, (_, row) in enumerate(baseline_sample_100.iterrows(), 1):
    print(f"\n{idx}. Sentence: {row['sentence'][:100]}...")
    print(f"   Aspect: {row['aspect']:<40} | Sentiment: {row['sentiment']}")
print("ADVANCED MODEL - 100 Random Sentences")
for idx, (_, row) in enumerate(advanced_sample_100.iterrows(), 1):
    print(f"\n{idx}. Sentence: {row['sentence'][:100]}...")
    print(f"   Aspect: {row['aspect']:<40} | Sentiment: {row['sentiment']}")
# Out:
# BASELINE MODEL - 100 Random Sentences
#
# 1. Sentence: not only clean and spacious, it is central to everything you need....
#    Aspect: host_and_property                        | Sentiment: negative
#
# 2. Sentence: <br/>the location was central to all the things you need to do, with some of the main attractions on...
#    Aspect: walkability                              | Sentiment: positive
#
# 3. Sentence: <br/>he did everything to make us feel like at home....
#    Aspect: atmosphere_ambiance                      | Sentiment: positive
#
# 4. Sentence: the apartment is on the second floor, which is reachable by steep stairs only....
#    Aspect: host_and_property                        | Sentiment: neutral
#
# 5. Sentence: dario was very responsive, proactive with recommendations, and friendly....
#    Aspect: host_communication                       | Sentiment: positive
#
# 6. Sentence: peter's after dark or waiting for the bus during the dark at the couple of stops located near the ap...
#    Aspect: host_and_property                        | Sentiment: negative
#
# 7. Sentence: giacomo was a great host very responsive to whatever was needed....
#    Aspect: host_communication                       | Sentiment: positive
#
# 8. Sentence: the apartment was a penthouse is a beautiful neighborhood next to the coliseum....
#    Aspect: apartment_appearance                     | Sentiment: positive
#
# 9. Sentence: the beds were very comfortable and our host was fantastic!...
#    Aspect: cleanliness                              | Sentiment: positive
#
# 10. Sentence: kitchen and eating area is perfect....
#    Aspect: apartment_capacity                       | Sentiment: positive
#
# 11. Sentence: the metro station is very close (maybe 15min walk)....
#    Aspect: transport_connectivity                   | Sentiment: neutral
#
# 12. Sentence: apartment is super clean with at excellent location...
#    Aspect: host_and_property                        | Sentiment: positive
#
# 13. Sentence: walking distance to all of them....
#    Aspect: walkability                              | Sentiment: neutral
#
# 14. Sentence: in particular the terrace we have experienced to be perfect for having an afternoon salad in the sun...
#    Aspect: location_close_center                    | Sentiment: positive
#
# 15. Sentence: extremely close to the vatican (2 min walk to museums, 10 min walk to st peters) and either a pleasa...
#    Aspect: walkability                              | Sentiment: positive
#
# 16. Sentence: a little shady neighbourhood at night but conveniently close to central station....
#    Aspect: transport_connectivity                   | Sentiment: neutral
#
# 17. Sentence: close to restaurants ecc in the gorgeous neighborhood of trastevere....
#    Aspect: dining_entertainment                     | Sentiment: positive
#
# 18. Sentence: <br/> <br/>silvia also arranged a car to take us to the airport when we left; it was great to have t...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 19. Sentence: the neighbouring streets are so lively, full of great bars, restaurants and markets but the apartmen...
#    Aspect: dining_entertainment                     | Sentiment: positive
#
# 20. Sentence: spacious, clean and accessible....
#    Aspect: host_and_property                        | Sentiment: positive
#
# 21. Sentence: ana maria was very reactive, friendly and we found the apartment very well renovated and totally in ...
#    Aspect: host_and_property                        | Sentiment: positive
#
# 22. Sentence: this nocarz’s location is perfect!...
#    Aspect: location_close_center                    | Sentiment: positive
#
# 23. Sentence: <br/>communication and expectations were clear and helpful!...
#    Aspect: host_communication                       | Sentiment: positive
#
# 24. Sentence: the view, the location, the cleanliness and homie feel made our stay perfect....
#    Aspect: location_close_center                    | Sentiment: positive
#
# 25. Sentence: very close walk to the vatican and the train station....
#    Aspect: transport_connectivity                   | Sentiment: neutral
#
# 26. Sentence: i would definitely stay at cristina's place again....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 27. Sentence: super apartment, top location and fantastic host....
#    Aspect: host_and_property                        | Sentiment: positive
#
# 28. Sentence: excellent host beautiful apartment thank you...
#    Aspect: apartment_appearance                     | Sentiment: positive
#
# 29. Sentence: this is a nice apartment that is very conveniently located in the city....
#    Aspect: cleanliness                              | Sentiment: positive
#
# 30. Sentence: <br/>masto restaurant one block down was superb!<br/>regarding prior reviewer complaints: this prope...
#    Aspect: overall_positive                         | Sentiment: negative
#
# 31. Sentence: <br/> <br/>upon arrival we were met by dario's lovely mother who showed us round and provided us wit...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 32. Sentence: will definitely go back, highly recommended!...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 33. Sentence: nice comfortable place, well worth the price....
#    Aspect: cleanliness                              | Sentiment: positive
#
# 34. Sentence: we were greeted by a nice associate of vito's and he explained all details of the apt....
#    Aspect: cleanliness                              | Sentiment: positive
#
# 35. Sentence: certainly a place to stay...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 36. Sentence: the high quality of the materials - wood floor, kitchen, lighting - makes you feel that you are in a...
#    Aspect: apartment_capacity                       | Sentiment: neutral
#
# 37. Sentence: the air conditioning was crucial too- so comfortable!...
#    Aspect: cleanliness                              | Sentiment: positive
#
# 38. Sentence: it is an older apartment but for me, it added to the charm of the place....
#    Aspect: host_and_property                        | Sentiment: positive
#
# 39. Sentence: simona's place had an amazing view....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 40. Sentence: brando was very responsive to my questions and greeted us when we arrived....
#    Aspect: host_communication                       | Sentiment: positive
#
# 41. Sentence: can’t stress how amazing this place is!...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 42. Sentence: +:<br/>this is an amazing location<br/>the apartment feels safe and spacious<br/>-:<br/>the bed was ...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 43. Sentence: very close to the colosseum and subway station which is a huge plus!...
#    Aspect: transport_connectivity                   | Sentiment: positive
#
# 44. Sentence: andrea was a great help to get us a baby stroller on rent & a cab back to fiumicino airport for 50€....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 45. Sentence: <br/> <br/>nani's apartment is ideally located in trastevere very close to great bars, restaurants a...
#    Aspect: walkability                              | Sentiment: positive
#
# 46. Sentence: 5 stars, right near the vatican, claudia is a great host, clean and spacious....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 47. Sentence: federica is a great host, it was very easy to communicate with her....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 48. Sentence: she also allowed us to check-in early, which was much appreciated after a long night of traveling fr...
#    Aspect: arrival_check_in_experience              | Sentiment: positive
#
# 49. Sentence: andrea suggested an eating joint near to the apartment and we tried it out....
#    Aspect: host_and_property                        | Sentiment: neutral
#
# 50. Sentence: it is also close to supermarket so it was very easy to pick up groceries on the way..the apartment i...
#    Aspect: host_and_property                        | Sentiment: positive
#
# 51. Sentence: the location was excellent as it it was close to all major attractions , numerous restaurants and a ...
#    Aspect: dining_entertainment                     | Sentiment: positive
#
# 52. Sentence: the location is awesome and stefano is a great host....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 53. Sentence: only a 10 minute walk to the vatican city....
#    Aspect: walkability                              | Sentiment: neutral
#
# 54. Sentence: we would definitely stay with alessio and michela again when visiting italy!...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 55. Sentence: there were many great restaurants, a bank atm for getting currency, and shops nearby....
#    Aspect: dining_entertainment                     | Sentiment: positive
#
# 56. Sentence: marco was very prompt in communications and we are really grateful that he could accommodate our cha...
#    Aspect: arrival_check_in_experience              | Sentiment: positive
#
# 57. Sentence: staying at federico's apartment in rome was the best experience....
#    Aspect: host_and_property                        | Sentiment: positive
#
# 58. Sentence: great location - very close to all major sites (10-30 mins, including vatican city)!...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 59. Sentence: he was very helpful and knowledgeable about the city and area....
#    Aspect: host_communication                       | Sentiment: positive
#
# 60. Sentence: julia s place in the monte area of rome was clean and comfortable....
#    Aspect: cleanliness                              | Sentiment: positive
#
# 61. Sentence: we walked from the apartment to campo dei fiori in around 10 minutes....
#    Aspect: host_and_property                        | Sentiment: neutral
#
# 62. Sentence: our host met us on the street as the apartment is in a village and difficult to navigate....
#    Aspect: host_and_property                        | Sentiment: negative
#
# 63. Sentence: the apartment was very clean, well decorated, and comfortable - just as advertised!...
#    Aspect: cleanliness                              | Sentiment: positive
#
# 64. Sentence: <br/>in short, we thank mary and her team....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 65. Sentence: charlotte, lorenzo’s assistant, was so warm, friendly, and helpful....
#    Aspect: host_communication                       | Sentiment: positive
#
# 66. Sentence: my entire stay was filled with authentic cuisine, shopping, and local living....
#    Aspect: overall_positive                         | Sentiment: neutral
#
# 67. Sentence: the hosts are very attentive and responsive....
#    Aspect: host_communication                       | Sentiment: positive
#
# 68. Sentence: he was extremely helpful and went way out of his way to help us organize tours and helped my parents...
#    Aspect: host_communication                       | Sentiment: positive
#
# 69. Sentence: also 5 minutes walk away from roma termini....
#    Aspect: walkability                              | Sentiment: neutral
#
# 70. Sentence: my daughter also loved playing the baby grand piano while we were there, which was fantastic!...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 71. Sentence: this apartment is very nice, recently renovated and clean, however, the area, building and apartment...
#    Aspect: host_and_property                        | Sentiment: negative
#
# 72. Sentence: <br/>staying here provided an authentic rome living experience in a beautifully decorated apartment ...
#    Aspect: host_and_property                        | Sentiment: positive
#
# 73. Sentence: everything was amazing and the communication was great since the start of the journey....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 74. Sentence: very good location, appartment is well equipped....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 75. Sentence: my family and i had an amazing stay at frederic’s condo in rome....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 76. Sentence: the view was breathtaking and such a great central location....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 77. Sentence: overall, really great value for money...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 78. Sentence: it's beautifully designed, but what's more important, it's also very accommodating and convenient in...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 79. Sentence: the supermarket is 10 minutes walk up a slight hill, the station another 10 mins....
#    Aspect: walkability                              | Sentiment: neutral
#
# 80. Sentence: <br/>the washer is easy to use....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 81. Sentence: hosts are very friendly with great suggestions on local restaurants....
#    Aspect: dining_entertainment                     | Sentiment: positive
#
# 82. Sentence: we got up to the apartment the electricity and air conditioning was completely out....
#    Aspect: host_and_property                        | Sentiment: neutral
#
# 83. Sentence: the apartment was fantastic, stylish and super clean....
#    Aspect: host_and_property                        | Sentiment: positive
#
# 84. Sentence: the appartment was nice, perfectly located to walk around major sites....
#    Aspect: walkability                              | Sentiment: positive
#
# 85. Sentence: great location, within walking distance to all major sites.<br/>we were a family of 6, and we were m...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 86. Sentence: the flat so clean and spotless she makes us feel at home and want us to have a good time in roma… so...
#    Aspect: atmosphere_ambiance                      | Sentiment: positive
#
# 87. Sentence: antonella’s studio was perfect for me and my boyfriend for a weekend in rome!...
#    Aspect: location_close_center                    | Sentiment: positive
#
# 88. Sentence: <br/> <br/>there's a little coop grocery right around the corner, which was very handy....
#    Aspect: overall_positive                         | Sentiment: neutral
#
# 89. Sentence: proactive, accommodating, friendly and responsive host, who went above and beyond by organizing tran...
#    Aspect: host_communication                       | Sentiment: positive
#
# 90. Sentence: charming, clean and spacious apartment with central location and super friendly host....
#    Aspect: host_and_property                        | Sentiment: positive
#
# 91. Sentence: there are ample restaurants and grocery stores within a five minute walk....
#    Aspect: walkability                              | Sentiment: neutral
#
# 92. Sentence: apartment always spotless…exact to the pictures....
#    Aspect: host_and_property                        | Sentiment: neutral
#
# 93. Sentence: xiuping is a very nice lady and she cooked us a tasty traditional chinese breakfast!...
#    Aspect: cleanliness                              | Sentiment: positive
#
# 94. Sentence: alex was very helpful and his place was very clean and comfortable....
#    Aspect: cleanliness                              | Sentiment: positive
#
# 95. Sentence: my husband and i, along with our four children and my brother-in-law, stayed in this beautiful apart...
#    Aspect: apartment_appearance                     | Sentiment: positive
#
# 96. Sentence: pro:<br/>-the host is nice<br/>-metro station 3 min<br/>-grocery shop 1 min<br/>con:<br/>-small flat...
#    Aspect: overall_positive                         | Sentiment: neutral
#
# 97. Sentence: a great bedroom, in a prime location....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 98. Sentence: in the vicinity you will find delicious restaurants, nice bars and even a supermarket that's open 24...
#    Aspect: dining_entertainment                     | Sentiment: positive
#
# 99. Sentence: christina was incredibly friendly and provided clear check-in instructions....
#    Aspect: arrival_check_in_experience              | Sentiment: positive
#
# 100. Sentence: amazing apartment in a “local” area of rome within walking distance to all major sites....
#    Aspect: walkability                              | Sentiment: positive
# ADVANCED MODEL - 100 Random Sentences
#
# 1. Sentence: they both waited for us while we dealt with our lost luggage....
#    Aspect: equipment_supplies                       | Sentiment: neutral
#
# 2. Sentence: the place is quite large for the air conditioning and when the weather is really warm, it's hard for...
#    Aspect: environmental_conditions                 | Sentiment: negative
#
# 3. Sentence: we enjoyed our stay and have no complaints!...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 4. Sentence: incredibly friendly hosts who truly care about making you feel at home....
#    Aspect: host_communication                       | Sentiment: positive
#
# 5. Sentence: chiara’s home was perfect for our trip to rome - all the amenities we needed, super close to a metro...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 6. Sentence: peter's basilica in a side street with little traffic....
#    Aspect: transport_proximity                      | Sentiment: neutral
#
# 7. Sentence: there was plenty of room for four guests with all the amenities we could wish for....
#    Aspect: apartment_amenities                      | Sentiment: positive
#
# 8. Sentence: it was spacious, spotlessly clean and in a quiet neighbourhood with nice cafes for breakfast....
#    Aspect: apartment_quality                        | Sentiment: positive
#
# 9. Sentence: and he recommended us the famous restaurant and the best sightseeing route....
#    Aspect: host_arrival_services                    | Sentiment: positive
#
# 10. Sentence: the restaurants he suggested were delicious!...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 11. Sentence: located right on st peter’s train station, and bus stop located at the front door, this apartment co...
#    Aspect: space_location_features                  | Sentiment: positive
#
# 12. Sentence: 무엇보다 나는 차를 렌트했기때문에 ztl을 피해 주차를 걱정했으나, 바로 옆 다리건너편에 유료주차장(8시간당 4유로)이 있어서 저렴하게 잘 이용했습니다....
#    Aspect: equipment_supplies                       | Sentiment: neutral
#
# 13. Sentence: unsere 4 jährige tochter hat sich dort vom ersten moment an sehr wohl gefühlt....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 14. Sentence: fomos muito bem recebidos por ana....
#    Aspect: host_communication                       | Sentiment: positive
#
# 15. Sentence: maurizio was so great....
#    Aspect: host_communication                       | Sentiment: positive
#
# 16. Sentence: lovely big place....
#    Aspect: location_quality                         | Sentiment: positive
#
# 17. Sentence: the apartment was in a fantastic location - close to vatican city and a short walk to many great res...
#    Aspect: space_location_features                  | Sentiment: positive
#
# 18. Sentence: l'appartement est parfaitement situé et fonctionnel, et l'accueil de paola a été très sympathique....
#    Aspect: host_communication                       | Sentiment: positive
#
# 19. Sentence: dank diesem gemütlichen nocarz haben wir uns sofort wie zuhause gefühlt....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 20. Sentence: maurizio‘s apartment is fantastic....
#    Aspect: space_location_features                  | Sentiment: positive
#
# 21. Sentence: this was very unprofessional and also unethical - we still have not found a suitable place for the l...
#    Aspect: equipment_supplies                       | Sentiment: negative
#
# 22. Sentence: el edificio es super tranquilo y tiene un garage si lo necesitan a 20 mts, un poco caro eso si....
#    Aspect: transport_proximity                      | Sentiment: neutral
#
# 23. Sentence: can't imagine a better place to stay, so many great restaurants and bars in the neighborhood....
#    Aspect: neighborhood_services                    | Sentiment: positive
#
# 24. Sentence: she has wonderful information about rome and the vatican....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 25. Sentence: easy to move around from close to metro and within walking distance as an alternative....
#    Aspect: transport_proximity                      | Sentiment: positive
#
# 26. Sentence: we stayed at maria luisa and riccardo's apartment just one day (unfortunately!...
#    Aspect: equipment_supplies                       | Sentiment: negative
#
# 27. Sentence: it is in a great location and the host is very responsive....
#    Aspect: host_communication                       | Sentiment: positive
#
# 28. Sentence: beautiful wood ceilings and tasteful decor throughout....
#    Aspect: location_quality                         | Sentiment: positive
#
# 29. Sentence: we were so close to so many fun locations....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 30. Sentence: il b&b di andrea è stato il migliore alloggio che abbiamo mai utilizzato tramite nocarz e senza dubb...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 31. Sentence: el anfitrión y el apartamento......
#    Aspect: host_communication                       | Sentiment: neutral
#
# 32. Sentence: it was in a perfect location, very close to the train station and within an adventurous walk or easy...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 33. Sentence: <br/>- broken was a toilet seat in one of the bathrooms and the sink....
#    Aspect: infrastructure_accessibility             | Sentiment: negative
#
# 34. Sentence: alessandro is a great host, really reachable and kind....
#    Aspect: host_communication                       | Sentiment: positive
#
# 35. Sentence: dit was wat weinig voor ons gezelschap van 5 personen....
#    Aspect: infrastructure_accessibility             | Sentiment: negative
#
# 36. Sentence: das zimmer war schön eingerichtet und ruhig....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 37. Sentence: i would highly recommend his place to anyone looking to visit rome....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 38. Sentence: amazing location - everything is walkable....
#    Aspect: location_quality                         | Sentiment: positive
#
# 39. Sentence: per farla breve alle 10.30 scopriamo le chiavi le ha il negozio pachistano sotto l appartamento, un ...
#    Aspect: overall_positive                         | Sentiment: negative
#
# 40. Sentence: in una gio fredda ed umida farsi u tè caldo dopo una camminata lunghissima è stato memorabile....
#    Aspect: apartment_amenities                      | Sentiment: positive
#
# 41. Sentence: marzia responds to any requests very promptly....
#    Aspect: host_communication                       | Sentiment: positive
#
# 42. Sentence: linge de lit et serviettes propres et de qualité.<br/>le logement mérite des rénovations au niveau d...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 43. Sentence: comunicazione e disponibilità del proprietario ottime....
#    Aspect: host_communication                       | Sentiment: positive
#
# 44. Sentence: lovely to be greeted and shown around when we arrived....
#    Aspect: host_arrival_services                    | Sentiment: positive
#
# 45. Sentence: the apartment was exactly as pictured and was in a great location....
#    Aspect: apartment_quality                        | Sentiment: positive
#
# 46. Sentence: <br/>the apartment was clean, accessible, and marco was a delight to communicate with during our sta...
#    Aspect: apartment_quality                        | Sentiment: positive
#
# 47. Sentence: definitely recommend it to friends....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 48. Sentence: ruhige und sichere lage, ein bisschen ausserhalb vom zentrum, aber top....
#    Aspect: transport_proximity                      | Sentiment: positive
#
# 49. Sentence: it was also strangely configured....
#    Aspect: infrastructure_accessibility             | Sentiment: negative
#
# 50. Sentence: we were greeted by alessandro's wife as he was busy with work....
#    Aspect: host_arrival_services                    | Sentiment: neutral
#
# 51. Sentence: ideale sia per una famiglia come noi che per due coppie di amici....
#    Aspect: host_communication                       | Sentiment: positive
#
# 52. Sentence: the accommodation was perfect for a short trip to rom!...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 53. Sentence: we would happily book it again if back in rome....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 54. Sentence: a cab ride never cost more than €10....
#    Aspect: transport_proximity                      | Sentiment: neutral
#
# 55. Sentence: my partner and i absolutely loved our short stay in rome in julia’s air bnb....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 56. Sentence: also, when i visit naples in the future, i will look at their other property!...
#    Aspect: overall_positive                         | Sentiment: neutral
#
# 57. Sentence: watch your heads on the lofted ceilings and you will love the place too....
#    Aspect: location_quality                         | Sentiment: positive
#
# 58. Sentence: good accommodation in good price in a super location...
#    Aspect: location_quality                         | Sentiment: positive
#
# 59. Sentence: beautiful little apartment tucked up into the top of a cute building 5 minutes from the spanish step...
#    Aspect: space_location_features                  | Sentiment: positive
#
# 60. Sentence: we stayed at the roma apartment for six nights for a family trip of 9 people, ages 4 to 63....
#    Aspect: overall_positive                         | Sentiment: neutral
#
# 61. Sentence: i will highly recommend to my friends....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 62. Sentence: it’s exactly what you think a rome apartment is when you are dreaming of coming here....
#    Aspect: overall_positive                         | Sentiment: neutral
#
# 63. Sentence: a lungo andare, per 4 ospiti, potrebbe risultare leggermente piccola, soprattutto per la cucina e il...
#    Aspect: overall_positive                         | Sentiment: negative
#
# 64. Sentence: daria was incredibly helpful and answering all of our questions leading up to our trip and during ou...
#    Aspect: host_arrival_services                    | Sentiment: positive
#
# 65. Sentence: très facilement joignable par whatsapp, nous avons apprécié nos échanges en français ^^...
#    Aspect: host_communication                       | Sentiment: positive
#
# 66. Sentence: would highly recommend this apartment for travelers to rome....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 67. Sentence: easy to check in (also at night), a clean and beautiful room and very friendly hosts!...
#    Aspect: apartment_quality                        | Sentiment: positive
#
# 68. Sentence: the place was exactly as advertised....
#    Aspect: apartment_quality                        | Sentiment: positive
#
# 69. Sentence: it was lovely to meet you and your son <3...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 70. Sentence: el alojamiento de alessandro es ideal para viajar a conocer roma principalmente por la ubicación en ...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 71. Sentence: wir waren mit unserem 13-jährigen sohn da, der das schöne zusätzliche zimmer ganz für sich sehr geno...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 72. Sentence: splendida location nel cuore di roma a 2 passi da colosseo,fori romani, circo massimo,….<br/>apparta...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 73. Sentence: we felt very welcome, comfortable and will totally recommend the place to stay at if you want to exp...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 74. Sentence: the place was just as i imagined!!!...
#    Aspect: apartment_quality                        | Sentiment: positive
#
# 75. Sentence: fabio treated us like we were family....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 76. Sentence: fabulous stay at beatrice’s place....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 77. Sentence: lots of good restaurant recommendations, close to the metro station, and very quiet at night!...
#    Aspect: neighborhood_services                    | Sentiment: positive
#
# 78. Sentence: i recommend stay here 100%....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 79. Sentence: had a great stay at danila's flat,it was clean and tidy and in a great location for visiting rome....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 80. Sentence: parking is hard in rome but with help from our host we were able to find parking....
#    Aspect: host_arrival_services                    | Sentiment: neutral
#
# 81. Sentence: with our room we got daily breakfast coupons at a local cafe (just around the corner) serving delici...
#    Aspect: apartment_amenities                      | Sentiment: positive
#
# 82. Sentence: and we especially loved the restaurants that she recommended within walking distance....
#    Aspect: host_arrival_services                    | Sentiment: positive
#
# 83. Sentence: ottima posizione per accedere all'ospedale san camillo....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 84. Sentence: el alojamiento tenía los servicios que se anuncian y todo cómodo!...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 85. Sentence: the apartment is as perfect as described!...
#    Aspect: apartment_quality                        | Sentiment: positive
#
# 86. Sentence: the apartment was clean, modern, and the terrace was great....
#    Aspect: apartment_quality                        | Sentiment: positive
#
# 87. Sentence: sylvia is the ultimate host!...
#    Aspect: host_communication                       | Sentiment: positive
#
# 88. Sentence: and not at times that were convenient and when we would not be in apartment....
#    Aspect: infrastructure_accessibility             | Sentiment: negative
#
# 89. Sentence: excellent kitchen....
#    Aspect: location_quality                         | Sentiment: positive
#
# 90. Sentence: muy cerca de la estación termini que es un plus para la llegada y la salida al aeropuertoy estación ...
#    Aspect: transport_proximity                      | Sentiment: positive
#
# 91. Sentence: l'appartamento era esattamente come in foto, ottimo per un breve soggiorno anche per un gruppo folto...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 92. Sentence: apartment was immaculate, had everything we needed, attentive & seamless checkin/out with the housek...
#    Aspect: apartment_quality                        | Sentiment: positive
#
# 93. Sentence: the place was clean and very central to places around the colosseum....
#    Aspect: apartment_quality                        | Sentiment: positive
#
# 94. Sentence: the apartment can use some cleaning here and there....
#    Aspect: space_location_features                  | Sentiment: neutral
#
# 95. Sentence: we had a great time in his nocarz ;)...
#    Aspect: overall_positive                         | Sentiment: positive
#
# 96. Sentence: cozy place and the washing machine is very helpfull....
#    Aspect: apartment_amenities                      | Sentiment: positive
#
# 97. Sentence: le logement était parfait pour notre grande famille de 10 personnes....
#    Aspect: overall_positive                         | Sentiment: positive
#
# 98. Sentence: sabrina was very responsive and helpful, giving us a late check out so we could squeeze in one final...
#    Aspect: host_arrival_services                    | Sentiment: positive
#
# 99. Sentence: many major tourist attractions in easy walking distance....
#    Aspect: transport_proximity                      | Sentiment: positive
#
# 100. Sentence: muito perto de metrôs e facilidades de mercados e restaurantes....
#    Aspect: host_communication                       | Sentiment: positive

# %% [markdown]
# # Wyniki ręcznej ewaluacji modeli
#
# ## BASELINE MODEL (100 zdań)
#
# **Aspect accuracy:**
# - Strict: 50.0% (50/100)
# - Relaxed: 55.0% (55/100)
#
# **Sentiment accuracy:** 98.0% (98/100)
#
# ## ADVANCED MODEL (100 zdań)
#
# **Aspect accuracy:**
# - Strict: 60.0% (60/100)
# - Relaxed: 84.0% (84/100)
#
# **Sentiment accuracy:** 95.0% (95/100)
